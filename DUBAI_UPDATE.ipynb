# %% [markdown]
# Update DUBAI Database

# %%
import pandas as pd
import sqlite3
import traceback
import sys

df = pd.read_excel(r"C:\Users\b.todorov\Desktop\db.XLSX")
db_path = r"S:\Warehouse dept\Inventory control\Reporting and dashboards\Bin's Counting DUBAI\DUBAI\DATABASE\countings_dubai.db"
df = df['Storage Bin']
conn = sqlite3.connect(db_path)
curs = conn.cursor()

try:
    for bin in df:
        #if bin.startswith('C'):
            curs.execute(f'update countings set Counted = 1 where "{bin}" = Bin')
            print(f'Updating DUBAI Database with Bin {bin}')
            total = list(curs.execute(f'SELECT COUNT(*) FROM countings WHERE Counted > 0;'))
            print(str(total[0]))
    conn.commit()
except sqlite3.Error as err:
        print('SQLite error: %s' % (' '.join(err.args)))
        print("Exception class is: ", err.__class__)
        print('SQLite traceback: ')
        exc_type, exc_value, exc_tb = sys.exc_info()
        print(traceback.format_exception(exc_type, exc_value, exc_tb))

curs.close()
conn.close()
# Out:
# Updating DUBAI Database with Bin CA011020
# (4523,)
# Updating DUBAI Database with Bin CA011030
# (4523,)
# Updating DUBAI Database with Bin CA011040
# (4523,)
# Updating DUBAI Database with Bin CA011050
# (4523,)
# Updating DUBAI Database with Bin CA011050
# (4523,)
# Updating DUBAI Database with Bin CA024070
# (4523,)
# Updating DUBAI Database with Bin CA024060
# (4523,)
# Updating DUBAI Database with Bin A-CA-IN-006
# (4523,)
# Updating DUBAI Database with Bin A-CA-IN-007
# (4523,)
# Updating DUBAI Database with Bin A-CA-IN-011
# (4523,)
# Updating DUBAI Database with Bin A-CA-IN-013
# (4523,)
# Updating DUBAI Database with Bin A-CA-IN-012
# (4523,)
# Updating DUBAI Database with Bin A-CA-IN-017
# (4523,)
# Updating DUBAI Database with Bin A-CA-IN-008
# (4523,)
# Updating DUBAI Database with Bin A-CA-IN-010
# (4523,)
# Updating DUBAI Database with Bin A-CA-IN-015
# (4523,)
# Updating DUBAI Database with Bin A-CA-IN-014
# (4523,)
# Updating DUBAI Database with Bin A-CA-IN-016
# (4523,)
# Updating DUBAI Database with Bin A-CA-IN-009
# (4523,)
# Updating DUBAI Database with Bin A-CA-IN-005
# (4523,)
# Updating DUBAI Database with Bin CA013020
# (4523,)
# Updating DUBAI Database with Bin CA013030
# (4523,)
# Updating DUBAI Database with Bin CA013040
# (4523,)
# Updating DUBAI Database with Bin CA013050
# (4523,)
# Updating DUBAI Database with Bin CA011020
# (4523,)
# Updating DUBAI Database with Bin CA011030
# (4523,)
# Updating DUBAI Database with Bin CA011040
# (4523,)
# Updating DUBAI Database with Bin CA023020
# (4523,)
# Updating DUBAI Database with Bin CA011050
# (4523,)
# Updating DUBAI Database with Bin CA011050
# (4523,)
# Updating DUBAI Database with Bin CA023030
# (4523,)
# Updating DUBAI Database with Bin CB071020
# (4523,)
# Updating DUBAI Database with Bin CB071030
# (4523,)
# Updating DUBAI Database with Bin CB071040
# (4523,)
# Updating DUBAI Database with Bin CB064020
# (4523,)
# Updating DUBAI Database with Bin CB064030
# (4523,)
# Updating DUBAI Database with Bin CB063040
# (4523,)
# Updating DUBAI Database with Bin CB064040
# (4523,)
# Updating DUBAI Database with Bin CB064050
# (4523,)
# Updating DUBAI Database with Bin CB063050
# (4523,)
# Updating DUBAI Database with Bin CB071010
# (4523,)
# Updating DUBAI Database with Bin CB171050
# (4523,)
# Updating DUBAI Database with Bin CB171050
# (4523,)
# Updating DUBAI Database with Bin CB163050
# (4523,)
# Updating DUBAI Database with Bin CB163050
# (4523,)
# Updating DUBAI Database with Bin CB164050
# (4523,)
# Updating DUBAI Database with Bin CB164050
# (4523,)
# Updating DUBAI Database with Bin CB173010
# (4523,)
# Updating DUBAI Database with Bin CB171010
# (4523,)
# Updating DUBAI Database with Bin CB173020
# (4523,)
# Updating DUBAI Database with Bin CB171020
# (4523,)
# Updating DUBAI Database with Bin CB171040
# (4523,)
# Updating DUBAI Database with Bin CB171030
# (4523,)
# Updating DUBAI Database with Bin CB164010
# (4523,)
# Updating DUBAI Database with Bin CB164020
# (4523,)
# Updating DUBAI Database with Bin CB164030
# (4523,)
# Updating DUBAI Database with Bin CB164040
# (4523,)
# Updating DUBAI Database with Bin CA023020
# (4523,)
# Updating DUBAI Database with Bin CA023030
# (4523,)
# Updating DUBAI Database with Bin CA024050
# (4523,)
# Updating DUBAI Database with Bin CA014020
# (4523,)
# Updating DUBAI Database with Bin CA031020
# (4523,)
# Updating DUBAI Database with Bin CA014030
# (4523,)
# Updating DUBAI Database with Bin CA031030
# (4523,)
# Updating DUBAI Database with Bin CA031040
# (4523,)
# Updating DUBAI Database with Bin CA014040
# (4523,)
# Updating DUBAI Database with Bin CA014050
# (4523,)
# Updating DUBAI Database with Bin CA031050
# (4523,)
# Updating DUBAI Database with Bin CA031050
# (4523,)
# Updating DUBAI Database with Bin CA021020
# (4523,)
# Updating DUBAI Database with Bin CA024020
# (4523,)
# Updating DUBAI Database with Bin CA021030
# (4523,)
# Updating DUBAI Database with Bin CA024030
# (4523,)
# Updating DUBAI Database with Bin CA024040
# (4523,)
# Updating DUBAI Database with Bin CA021040
# (4523,)
# Updating DUBAI Database with Bin CA023040
# (4523,)
# Updating DUBAI Database with Bin CA021050
# (4523,)
# Updating DUBAI Database with Bin CA021050
# (4523,)
# Updating DUBAI Database with Bin CA023050
# (4523,)
# Updating DUBAI Database with Bin CA041050
# (4523,)
# Updating DUBAI Database with Bin CA033020
# (4523,)
# Updating DUBAI Database with Bin CA034020
# (4523,)
# Updating DUBAI Database with Bin CA033030
# (4523,)
# Updating DUBAI Database with Bin CA034030
# (4523,)
# Updating DUBAI Database with Bin CA033040
# (4523,)
# Updating DUBAI Database with Bin CA034040
# (4523,)
# Updating DUBAI Database with Bin CA033050
# (4523,)
# Updating DUBAI Database with Bin CA041020
# (4523,)
# Updating DUBAI Database with Bin CA043020
# (4523,)
# Updating DUBAI Database with Bin CA044020
# (4523,)
# Updating DUBAI Database with Bin CA044030
# (4523,)
# Updating DUBAI Database with Bin CA041030
# (4523,)
# Updating DUBAI Database with Bin CA041040
# (4523,)
# Updating DUBAI Database with Bin CA043040
# (4523,)
# Updating DUBAI Database with Bin CA044040
# (4523,)
# Updating DUBAI Database with Bin CA043050
# (4523,)
# Updating DUBAI Database with Bin CA044050
# (4523,)
# Updating DUBAI Database with Bin CA034050
# (4523,)
# Updating DUBAI Database with Bin CA043030
# (4523,)
# Updating DUBAI Database with Bin CA051020
# (4523,)
# Updating DUBAI Database with Bin CA053020
# (4523,)
# Updating DUBAI Database with Bin CA051030
# (4523,)
# Updating DUBAI Database with Bin CA053030
# (4523,)
# Updating DUBAI Database with Bin CA053030
# (4523,)
# Updating DUBAI Database with Bin CA053030
# (4523,)
# Updating DUBAI Database with Bin CA051040
# (4523,)
# Updating DUBAI Database with Bin CA053040
# (4523,)
# Updating DUBAI Database with Bin CA054040
# (4523,)
# Updating DUBAI Database with Bin CA054020
# (4523,)
# Updating DUBAI Database with Bin CA051050
# (4523,)
# Updating DUBAI Database with Bin CA053050
# (4523,)
# Updating DUBAI Database with Bin CA054050
# (4523,)
# Updating DUBAI Database with Bin CA061020
# (4523,)
# Updating DUBAI Database with Bin CA063020
# (4523,)
# Updating DUBAI Database with Bin CA063040
# (4523,)
# Updating DUBAI Database with Bin CA061040
# (4523,)
# Updating DUBAI Database with Bin CA063050
# (4523,)
# Updating DUBAI Database with Bin CA061050
# (4523,)
# Updating DUBAI Database with Bin CA054030
# (4523,)
# Updating DUBAI Database with Bin CA063030
# (4523,)
# Updating DUBAI Database with Bin CA061030
# (4523,)
# Updating DUBAI Database with Bin CA071060
# (4523,)
# Updating DUBAI Database with Bin CA071070
# (4523,)
# Updating DUBAI Database with Bin CA072010
# (4523,)
# Updating DUBAI Database with Bin CA072020
# (4523,)
# Updating DUBAI Database with Bin CA072030
# (4523,)
# Updating DUBAI Database with Bin CA072040
# (4523,)
# Updating DUBAI Database with Bin CA072050
# (4523,)
# Updating DUBAI Database with Bin CA072060
# (4523,)
# Updating DUBAI Database with Bin CA072070
# (4523,)
# Updating DUBAI Database with Bin CA064060
# (4523,)
# Updating DUBAI Database with Bin CA064070
# (4523,)
# Updating DUBAI Database with Bin CA071020
# (4523,)
# Updating DUBAI Database with Bin CA071030
# (4523,)
# Updating DUBAI Database with Bin CA071040
# (4523,)
# Updating DUBAI Database with Bin CA071050
# (4523,)
# Updating DUBAI Database with Bin CA064020
# (4523,)
# Updating DUBAI Database with Bin CA064030
# (4523,)
# Updating DUBAI Database with Bin CA064040
# (4523,)
# Updating DUBAI Database with Bin CA064050
# (4523,)
# Updating DUBAI Database with Bin CA071010
# (4523,)
# Updating DUBAI Database with Bin CA073060
# (4523,)
# Updating DUBAI Database with Bin CA074060
# (4523,)
# Updating DUBAI Database with Bin CA073070
# (4523,)
# Updating DUBAI Database with Bin CA074070
# (4523,)
# Updating DUBAI Database with Bin CA081060
# (4523,)
# Updating DUBAI Database with Bin CA083060
# (4523,)
# Updating DUBAI Database with Bin CA084060
# (4523,)
# Updating DUBAI Database with Bin CA081070
# (4523,)
# Updating DUBAI Database with Bin CA083070
# (4523,)
# Updating DUBAI Database with Bin CA082040
# (4523,)
# Updating DUBAI Database with Bin CA082060
# (4523,)
# Updating DUBAI Database with Bin CA082070
# (4523,)
# Updating DUBAI Database with Bin CA082010
# (4523,)
# Updating DUBAI Database with Bin CA082020
# (4523,)
# Updating DUBAI Database with Bin CA082030
# (4523,)
# Updating DUBAI Database with Bin CA082050
# (4523,)
# Updating DUBAI Database with Bin CA074010
# (4523,)
# Updating DUBAI Database with Bin CA073010
# (4523,)
# Updating DUBAI Database with Bin CA073020
# (4523,)
# Updating DUBAI Database with Bin CA074020
# (4523,)
# Updating DUBAI Database with Bin CA073030
# (4523,)
# Updating DUBAI Database with Bin CA074030
# (4523,)
# Updating DUBAI Database with Bin CA073040
# (4523,)
# Updating DUBAI Database with Bin CA074040
# (4523,)
# Updating DUBAI Database with Bin CA073050
# (4523,)
# Updating DUBAI Database with Bin CA074050
# (4523,)
# Updating DUBAI Database with Bin CA081010
# (4523,)
# Updating DUBAI Database with Bin CA083010
# (4523,)
# Updating DUBAI Database with Bin CA084010
# (4523,)
# Updating DUBAI Database with Bin CA083020
# (4523,)
# Updating DUBAI Database with Bin CA084020
# (4523,)
# Updating DUBAI Database with Bin CA081020
# (4523,)
# Updating DUBAI Database with Bin CA083030
# (4523,)
# Updating DUBAI Database with Bin CA084030
# (4523,)
# Updating DUBAI Database with Bin CA083040
# (4523,)
# Updating DUBAI Database with Bin CA084040
# (4523,)
# Updating DUBAI Database with Bin CA081030
# (4523,)
# Updating DUBAI Database with Bin CA083050
# (4523,)
# Updating DUBAI Database with Bin CA081050
# (4523,)
# Updating DUBAI Database with Bin CA084050
# (4523,)
# Updating DUBAI Database with Bin CA081040
# (4523,)
# Updating DUBAI Database with Bin CA091070
# (4523,)
# Updating DUBAI Database with Bin CA092010
# (4523,)
# Updating DUBAI Database with Bin CA092020
# (4523,)
# Updating DUBAI Database with Bin CA092030
# (4523,)
# Updating DUBAI Database with Bin CA092040
# (4523,)
# Updating DUBAI Database with Bin CA092050
# (4523,)
# Updating DUBAI Database with Bin CA092060
# (4523,)
# Updating DUBAI Database with Bin CA092070
# (4523,)
# Updating DUBAI Database with Bin CA084070
# (4523,)
# Updating DUBAI Database with Bin CA091010
# (4523,)
# Updating DUBAI Database with Bin CA093010
# (4523,)
# Updating DUBAI Database with Bin CA091020
# (4523,)
# Updating DUBAI Database with Bin CA093020
# (4523,)
# Updating DUBAI Database with Bin CA091030
# (4523,)
# Updating DUBAI Database with Bin CA093030
# (4523,)
# Updating DUBAI Database with Bin CA091040
# (4523,)
# Updating DUBAI Database with Bin CA093050
# (4523,)
# Updating DUBAI Database with Bin CA091050
# (4523,)
# Updating DUBAI Database with Bin CA093040
# (4523,)
# Updating DUBAI Database with Bin CA091060
# (4523,)
# Updating DUBAI Database with Bin CA093060
# (4523,)
# Updating DUBAI Database with Bin CA011020
# (4523,)
# Updating DUBAI Database with Bin A-CA-IN-018
# (4523,)
# Updating DUBAI Database with Bin A-CB-IN-001
# (4523,)
# Updating DUBAI Database with Bin A-CB-IN-002
# (4523,)
# Updating DUBAI Database with Bin CA011010
# (4523,)
# Updating DUBAI Database with Bin CA041050
# (4523,)
# Updating DUBAI Database with Bin CA033020
# (4523,)
# Updating DUBAI Database with Bin CA034020
# (4523,)
# Updating DUBAI Database with Bin CA033030
# (4523,)
# Updating DUBAI Database with Bin CA034030
# (4523,)
# Updating DUBAI Database with Bin CA033040
# (4523,)
# Updating DUBAI Database with Bin CA034040
# (4523,)
# Updating DUBAI Database with Bin CA033050
# (4523,)
# Updating DUBAI Database with Bin CA041020
# (4523,)
# Updating DUBAI Database with Bin CA044020
# (4523,)
# Updating DUBAI Database with Bin CA044030
# (4523,)
# Updating DUBAI Database with Bin CA041030
# (4523,)
# Updating DUBAI Database with Bin CA041040
# (4523,)
# Updating DUBAI Database with Bin CA043040
# (4523,)
# Updating DUBAI Database with Bin CA044040
# (4523,)
# Updating DUBAI Database with Bin CA043050
# (4523,)
# Updating DUBAI Database with Bin CA044050
# (4523,)
# Updating DUBAI Database with Bin CA034050
# (4523,)
# Updating DUBAI Database with Bin CA043030
# (4523,)
# Updating DUBAI Database with Bin CA043020
# (4523,)
# Updating DUBAI Database with Bin CA011070
# (4523,)
# Updating DUBAI Database with Bin CA013070
# (4523,)
# Updating DUBAI Database with Bin CA014070
# (4523,)
# Updating DUBAI Database with Bin CA031070
# (4523,)
# Updating DUBAI Database with Bin CA033070
# (4523,)
# Updating DUBAI Database with Bin CA034070
# (4523,)
# Updating DUBAI Database with Bin CA021070
# (4523,)
# Updating DUBAI Database with Bin CA023070
# (4523,)
# Updating DUBAI Database with Bin CA041070
# (4523,)
# Updating DUBAI Database with Bin CA044070
# (4523,)
# Updating DUBAI Database with Bin CA043070
# (4523,)
# Updating DUBAI Database with Bin CA011060
# (4523,)
# Updating DUBAI Database with Bin CA014060
# (4523,)
# Updating DUBAI Database with Bin CA013060
# (4523,)
# Updating DUBAI Database with Bin CA031060
# (4523,)
# Updating DUBAI Database with Bin CA021060
# (4523,)
# Updating DUBAI Database with Bin CA024060
# (4523,)
# Updating DUBAI Database with Bin CA023060
# (4523,)
# Updating DUBAI Database with Bin CA024070
# (4523,)
# Updating DUBAI Database with Bin CA023030
# (4523,)
# Updating DUBAI Database with Bin CA044060
# (4523,)
# Updating DUBAI Database with Bin CA013020
# (4523,)
# Updating DUBAI Database with Bin CA013030
# (4523,)
# Updating DUBAI Database with Bin CA013040
# (4523,)
# Updating DUBAI Database with Bin CA011030
# (4523,)
# Updating DUBAI Database with Bin CA011040
# (4523,)
# Updating DUBAI Database with Bin CA011050
# (4523,)
# Updating DUBAI Database with Bin CA011050
# (4523,)
# Updating DUBAI Database with Bin CA014020
# (4523,)
# Updating DUBAI Database with Bin CA031020
# (4523,)
# Updating DUBAI Database with Bin CA014030
# (4523,)
# Updating DUBAI Database with Bin CA031030
# (4523,)
# Updating DUBAI Database with Bin CA031040
# (4523,)
# Updating DUBAI Database with Bin CA014040
# (4523,)
# Updating DUBAI Database with Bin CA014050
# (4523,)
# Updating DUBAI Database with Bin CA031050
# (4523,)
# Updating DUBAI Database with Bin CA031050
# (4523,)
# Updating DUBAI Database with Bin CA023020
# (4523,)
# Updating DUBAI Database with Bin CA024050
# (4523,)
# Updating DUBAI Database with Bin CA021020
# (4523,)
# Updating DUBAI Database with Bin CA024020
# (4523,)
# Updating DUBAI Database with Bin CA021030
# (4523,)
# Updating DUBAI Database with Bin CA024030
# (4523,)
# Updating DUBAI Database with Bin CA024040
# (4523,)
# Updating DUBAI Database with Bin CA021040
# (4523,)
# Updating DUBAI Database with Bin CA023040
# (4523,)
# Updating DUBAI Database with Bin CA023050
# (4523,)
# Updating DUBAI Database with Bin CA011020
# (4523,)
# Updating DUBAI Database with Bin CA051060
# (4523,)
# Updating DUBAI Database with Bin CA033060
# (4523,)
# Updating DUBAI Database with Bin CA034060
# (4523,)
# Updating DUBAI Database with Bin CA041060
# (4523,)
# Updating DUBAI Database with Bin CA043060
# (4523,)
# Updating DUBAI Database with Bin CA051020
# (4523,)
# Updating DUBAI Database with Bin CA051030
# (4523,)
# Updating DUBAI Database with Bin CA051040
# (4523,)
# Updating DUBAI Database with Bin CA051050
# (4523,)
# Updating DUBAI Database with Bin CA013050
# (4523,)
# Updating DUBAI Database with Bin CA021050
# (4523,)
# Updating DUBAI Database with Bin CA021050
# (4523,)
# Updating DUBAI Database with Bin CA051070
# (4523,)
# Updating DUBAI Database with Bin CA053070
# (4523,)
# Updating DUBAI Database with Bin CA054070
# (4523,)
# Updating DUBAI Database with Bin CA071020
# (4523,)
# Updating DUBAI Database with Bin CA054020
# (4523,)
# Updating DUBAI Database with Bin CA053060
# (4523,)
# Updating DUBAI Database with Bin CA054060
# (4523,)
# Updating DUBAI Database with Bin CA053020
# (4523,)
# Updating DUBAI Database with Bin CA053030
# (4523,)
# Updating DUBAI Database with Bin CA053030
# (4523,)
# Updating DUBAI Database with Bin CA053030
# (4523,)
# Updating DUBAI Database with Bin CA053040
# (4523,)
# Updating DUBAI Database with Bin CA054040
# (4523,)
# Updating DUBAI Database with Bin CA053050
# (4523,)
# Updating DUBAI Database with Bin CA054050
# (4523,)
# Updating DUBAI Database with Bin CA061020
# (4523,)
# Updating DUBAI Database with Bin CA054030
# (4523,)
# Updating DUBAI Database with Bin CA071060
# (4523,)
# Updating DUBAI Database with Bin CA071070
# (4523,)
# Updating DUBAI Database with Bin CA064060
# (4523,)
# Updating DUBAI Database with Bin CA064070
# (4523,)
# Updating DUBAI Database with Bin CA071030
# (4523,)
# Updating DUBAI Database with Bin CA071040
# (4523,)
# Updating DUBAI Database with Bin CA071050
# (4523,)
# Updating DUBAI Database with Bin CA064020
# (4523,)
# Updating DUBAI Database with Bin CA064030
# (4523,)
# Updating DUBAI Database with Bin CA064040
# (4523,)
# Updating DUBAI Database with Bin CA064050
# (4523,)
# Updating DUBAI Database with Bin CA071010
# (4523,)
# Updating DUBAI Database with Bin CA084070
# (4523,)
# Updating DUBAI Database with Bin CA091010
# (4523,)
# Updating DUBAI Database with Bin CA091020
# (4523,)
# Updating DUBAI Database with Bin CA113010
# (4523,)
# Updating DUBAI Database with Bin CA093070
# (4523,)
# Updating DUBAI Database with Bin CA094070
# (4523,)
# Updating DUBAI Database with Bin CA111070
# (4523,)
# Updating DUBAI Database with Bin CA101070
# (4523,)
# Updating DUBAI Database with Bin CA103070
# (4523,)
# Updating DUBAI Database with Bin CA104070
# (4523,)
# Updating DUBAI Database with Bin CA091070
# (4523,)
# Updating DUBAI Database with Bin CA111010
# (4523,)
# Updating DUBAI Database with Bin CA094010
# (4523,)
# Updating DUBAI Database with Bin CA094020
# (4523,)
# Updating DUBAI Database with Bin CA113020
# (4523,)
# Updating DUBAI Database with Bin CA111020
# (4523,)
# Updating DUBAI Database with Bin CA113030
# (4523,)
# Updating DUBAI Database with Bin CA111030
# (4523,)
# Updating DUBAI Database with Bin CA111040
# (4523,)
# Updating DUBAI Database with Bin CA094040
# (4523,)
# Updating DUBAI Database with Bin CA094030
# (4523,)
# Updating DUBAI Database with Bin CA094050
# (4523,)
# Updating DUBAI Database with Bin CA111050
# (4523,)
# Updating DUBAI Database with Bin CA094060
# (4523,)
# Updating DUBAI Database with Bin CA111060
# (4523,)
# Updating DUBAI Database with Bin CA093010
# (4523,)
# Updating DUBAI Database with Bin CA093020
# (4523,)
# Updating DUBAI Database with Bin CA091030
# (4523,)
# Updating DUBAI Database with Bin CA093030
# (4523,)
# Updating DUBAI Database with Bin CA091040
# (4523,)
# Updating DUBAI Database with Bin CA093050
# (4523,)
# Updating DUBAI Database with Bin CA091050
# (4523,)
# Updating DUBAI Database with Bin CA091060
# (4523,)
# Updating DUBAI Database with Bin CA093060
# (4523,)
# Updating DUBAI Database with Bin CA101010
# (4523,)
# Updating DUBAI Database with Bin CA103010
# (4523,)
# Updating DUBAI Database with Bin CA104020
# (4523,)
# Updating DUBAI Database with Bin CA103020
# (4523,)
# Updating DUBAI Database with Bin CA101020
# (4523,)
# Updating DUBAI Database with Bin CA101030
# (4523,)
# Updating DUBAI Database with Bin CA104030
# (4523,)
# Updating DUBAI Database with Bin CA103030
# (4523,)
# Updating DUBAI Database with Bin CA104040
# (4523,)
# Updating DUBAI Database with Bin CA101040
# (4523,)
# Updating DUBAI Database with Bin CA103040
# (4523,)
# Updating DUBAI Database with Bin CA103050
# (4523,)
# Updating DUBAI Database with Bin CA104050
# (4523,)
# Updating DUBAI Database with Bin CA103060
# (4523,)
# Updating DUBAI Database with Bin CA101060
# (4523,)
# Updating DUBAI Database with Bin CA104060
# (4523,)
# Updating DUBAI Database with Bin CA093040
# (4523,)
# Updating DUBAI Database with Bin CA104010
# (4523,)
# Updating DUBAI Database with Bin CA101050
# (4523,)
# Updating DUBAI Database with Bin CA062040
# (4523,)
# Updating DUBAI Database with Bin CA062040
# (4523,)
# Updating DUBAI Database with Bin CA062040
# (4523,)
# Updating DUBAI Database with Bin CA062040
# (4523,)
# Updating DUBAI Database with Bin CA113070
# (4523,)
# Updating DUBAI Database with Bin CA114070
# (4523,)
# Updating DUBAI Database with Bin CA131070
# (4523,)
# Updating DUBAI Database with Bin CA133070
# (4523,)
# Updating DUBAI Database with Bin CA134070
# (4523,)
# Updating DUBAI Database with Bin CA151070
# (4523,)
# Updating DUBAI Database with Bin CA153070
# (4523,)
# Updating DUBAI Database with Bin CA154070
# (4523,)
# Updating DUBAI Database with Bin CA121070
# (4523,)
# Updating DUBAI Database with Bin CA123070
# (4523,)
# Updating DUBAI Database with Bin CA124070
# (4523,)
# Updating DUBAI Database with Bin CA141070
# (4523,)
# Updating DUBAI Database with Bin CA143070
# (4523,)
# Updating DUBAI Database with Bin CA144070
# (4523,)
# Updating DUBAI Database with Bin CA114010
# (4523,)
# Updating DUBAI Database with Bin CA131010
# (4523,)
# Updating DUBAI Database with Bin CA134010
# (4523,)
# Updating DUBAI Database with Bin CA133010
# (4523,)
# Updating DUBAI Database with Bin CA154010
# (4523,)
# Updating DUBAI Database with Bin CA134020
# (4523,)
# Updating DUBAI Database with Bin CA114020
# (4523,)
# Updating DUBAI Database with Bin CA151020
# (4523,)
# Updating DUBAI Database with Bin CA153020
# (4523,)
# Updating DUBAI Database with Bin CA133020
# (4523,)
# Updating DUBAI Database with Bin CA154020
# (4523,)
# Updating DUBAI Database with Bin CA131020
# (4523,)
# Updating DUBAI Database with Bin CA114030
# (4523,)
# Updating DUBAI Database with Bin CA154030
# (4523,)
# Updating DUBAI Database with Bin CA131030
# (4523,)
# Updating DUBAI Database with Bin CA151030
# (4523,)
# Updating DUBAI Database with Bin CA134030
# (4523,)
# Updating DUBAI Database with Bin CA133030
# (4523,)
# Updating DUBAI Database with Bin CA153030
# (4523,)
# Updating DUBAI Database with Bin CA131040
# (4523,)
# Updating DUBAI Database with Bin CA133040
# (4523,)
# Updating DUBAI Database with Bin CA151040
# (4523,)
# Updating DUBAI Database with Bin CA153040
# (4523,)
# Updating DUBAI Database with Bin CA154040
# (4523,)
# Updating DUBAI Database with Bin CA113040
# (4523,)
# Updating DUBAI Database with Bin CA113050
# (4523,)
# Updating DUBAI Database with Bin CA153050
# (4523,)
# Updating DUBAI Database with Bin CA154050
# (4523,)
# Updating DUBAI Database with Bin CA133050
# (4523,)
# Updating DUBAI Database with Bin CA114050
# (4523,)
# Updating DUBAI Database with Bin CA131050
# (4523,)
# Updating DUBAI Database with Bin CA134050
# (4523,)
# Updating DUBAI Database with Bin CA151050
# (4523,)
# Updating DUBAI Database with Bin CA114040
# (4523,)
# Updating DUBAI Database with Bin CA113060
# (4523,)
# Updating DUBAI Database with Bin CA114060
# (4523,)
# Updating DUBAI Database with Bin CA133060
# (4523,)
# Updating DUBAI Database with Bin CA131060
# (4523,)
# Updating DUBAI Database with Bin CA134060
# (4523,)
# Updating DUBAI Database with Bin CA151060
# (4523,)
# Updating DUBAI Database with Bin CA153060
# (4523,)
# Updating DUBAI Database with Bin CA154060
# (4523,)
# Updating DUBAI Database with Bin CA123010
# (4523,)
# Updating DUBAI Database with Bin CA121010
# (4523,)
# Updating DUBAI Database with Bin CA124010
# (4523,)
# Updating DUBAI Database with Bin CA144010
# (4523,)
# Updating DUBAI Database with Bin CA143020
# (4523,)
# Updating DUBAI Database with Bin CA141020
# (4523,)
# Updating DUBAI Database with Bin CA121020
# (4523,)
# Updating DUBAI Database with Bin CA144020
# (4523,)
# Updating DUBAI Database with Bin CA124020
# (4523,)
# Updating DUBAI Database with Bin CA161020
# (4523,)
# Updating DUBAI Database with Bin CA123030
# (4523,)
# Updating DUBAI Database with Bin CA123030
# (4523,)
# Updating DUBAI Database with Bin CA121030
# (4523,)
# Updating DUBAI Database with Bin CA124030
# (4523,)
# Updating DUBAI Database with Bin CA121040
# (4523,)
# Updating DUBAI Database with Bin CA124040
# (4523,)
# Updating DUBAI Database with Bin CA141040
# (4523,)
# Updating DUBAI Database with Bin CA123040
# (4523,)
# Updating DUBAI Database with Bin CA143030
# (4523,)
# Updating DUBAI Database with Bin CA124050
# (4523,)
# Updating DUBAI Database with Bin CA141050
# (4523,)
# Updating DUBAI Database with Bin CA123050
# (4523,)
# Updating DUBAI Database with Bin CA121050
# (4523,)
# Updating DUBAI Database with Bin CA144050
# (4523,)
# Updating DUBAI Database with Bin CA143050
# (4523,)
# Updating DUBAI Database with Bin CA161010
# (4523,)
# Updating DUBAI Database with Bin CA161050
# (4523,)
# Updating DUBAI Database with Bin CA144030
# (4523,)
# Updating DUBAI Database with Bin CA161030
# (4523,)
# Updating DUBAI Database with Bin CA143060
# (4523,)
# Updating DUBAI Database with Bin CA144060
# (4523,)
# Updating DUBAI Database with Bin CA124060
# (4523,)
# Updating DUBAI Database with Bin CA141060
# (4523,)
# Updating DUBAI Database with Bin CA121060
# (4523,)
# Updating DUBAI Database with Bin CA123060
# (4523,)
# Updating DUBAI Database with Bin CA141010
# (4523,)
# Updating DUBAI Database with Bin CA123020
# (4523,)
# Updating DUBAI Database with Bin CA141030
# (4523,)
# Updating DUBAI Database with Bin CA143040
# (4523,)
# Updating DUBAI Database with Bin CA151010
# (4523,)
# Updating DUBAI Database with Bin CA153010
# (4523,)
# Updating DUBAI Database with Bin CA143010
# (4523,)
# Updating DUBAI Database with Bin CA161040
# (4523,)
# Updating DUBAI Database with Bin CA134040
# (4523,)
# Updating DUBAI Database with Bin CA144040
# (4523,)
# Updating DUBAI Database with Bin CA183040
# (4523,)
# Updating DUBAI Database with Bin CA171070
# (4523,)
# Updating DUBAI Database with Bin CA173070
# (4523,)
# Updating DUBAI Database with Bin CA174070
# (4523,)
# Updating DUBAI Database with Bin CA161070
# (4523,)
# Updating DUBAI Database with Bin CA163070
# (4523,)
# Updating DUBAI Database with Bin CA164070
# (4523,)
# Updating DUBAI Database with Bin CA181070
# (4523,)
# Updating DUBAI Database with Bin CA171010
# (4523,)
# Updating DUBAI Database with Bin CA173010
# (4523,)
# Updating DUBAI Database with Bin CA174020
# (4523,)
# Updating DUBAI Database with Bin CA173020
# (4523,)
# Updating DUBAI Database with Bin CA171020
# (4523,)
# Updating DUBAI Database with Bin CA174030
# (4523,)
# Updating DUBAI Database with Bin CA173030
# (4523,)
# Updating DUBAI Database with Bin CA171040
# (4523,)
# Updating DUBAI Database with Bin CA173040
# (4523,)
# Updating DUBAI Database with Bin CA171030
# (4523,)
# Updating DUBAI Database with Bin CA173050
# (4523,)
# Updating DUBAI Database with Bin CA173050
# (4523,)
# Updating DUBAI Database with Bin CA174050
# (4523,)
# Updating DUBAI Database with Bin CA174050
# (4523,)
# Updating DUBAI Database with Bin CA174040
# (4523,)
# Updating DUBAI Database with Bin CA171050
# (4523,)
# Updating DUBAI Database with Bin CA171050
# (4523,)
# Updating DUBAI Database with Bin CA183010
# (4523,)
# Updating DUBAI Database with Bin CA164010
# (4523,)
# Updating DUBAI Database with Bin CA163010
# (4523,)
# Updating DUBAI Database with Bin CA181020
# (4523,)
# Updating DUBAI Database with Bin CA163020
# (4523,)
# Updating DUBAI Database with Bin CA164020
# (4523,)
# Updating DUBAI Database with Bin CA183030
# (4523,)
# Updating DUBAI Database with Bin CA181030
# (4523,)
# Updating DUBAI Database with Bin CA164030
# (4523,)
# Updating DUBAI Database with Bin CA163030
# (4523,)
# Updating DUBAI Database with Bin CA183020
# (4523,)
# Updating DUBAI Database with Bin CA183020
# (4523,)
# Updating DUBAI Database with Bin CA163040
# (4523,)
# Updating DUBAI Database with Bin CA164040
# (4523,)
# Updating DUBAI Database with Bin CA163050
# (4523,)
# Updating DUBAI Database with Bin CA163050
# (4523,)
# Updating DUBAI Database with Bin CA164050
# (4523,)
# Updating DUBAI Database with Bin CA164050
# (4523,)
# Updating DUBAI Database with Bin CA183050
# (4523,)
# Updating DUBAI Database with Bin CA181050
# (4523,)
# Updating DUBAI Database with Bin CA181050
# (4523,)
# Updating DUBAI Database with Bin CA163060
# (4523,)
# Updating DUBAI Database with Bin CA161060
# (4523,)
# Updating DUBAI Database with Bin CA181010
# (4523,)
# Updating DUBAI Database with Bin CA173060
# (4523,)
# Updating DUBAI Database with Bin CA181060
# (4523,)
# Updating DUBAI Database with Bin CA174060
# (4523,)
# Updating DUBAI Database with Bin CA171060
# (4523,)
# Updating DUBAI Database with Bin CA164060
# (4523,)
# Updating DUBAI Database with Bin CA174010
# (4523,)
# Updating DUBAI Database with Bin CA183060
# (4523,)
# Updating DUBAI Database with Bin CA191070
# (4523,)
# Updating DUBAI Database with Bin CA193070
# (4523,)
# Updating DUBAI Database with Bin CA194070
# (4523,)
# Updating DUBAI Database with Bin CA183070
# (4523,)
# Updating DUBAI Database with Bin CA184070
# (4523,)
# Updating DUBAI Database with Bin CA201070
# (4523,)
# Updating DUBAI Database with Bin CA203070
# (4523,)
# Updating DUBAI Database with Bin CA204070
# (4523,)
# Updating DUBAI Database with Bin CA194060
# (4523,)
# Updating DUBAI Database with Bin CA193060
# (4523,)
# Updating DUBAI Database with Bin CA203060
# (4523,)
# Updating DUBAI Database with Bin CA201060
# (4523,)
# Updating DUBAI Database with Bin CA191010
# (4523,)
# Updating DUBAI Database with Bin CA193010
# (4523,)
# Updating DUBAI Database with Bin CA194010
# (4523,)
# Updating DUBAI Database with Bin CA191020
# (4523,)
# Updating DUBAI Database with Bin CA193020
# (4523,)
# Updating DUBAI Database with Bin CA194020
# (4523,)
# Updating DUBAI Database with Bin CA191030
# (4523,)
# Updating DUBAI Database with Bin CA194030
# (4523,)
# Updating DUBAI Database with Bin CA193030
# (4523,)
# Updating DUBAI Database with Bin CA191040
# (4523,)
# Updating DUBAI Database with Bin CA193040
# (4523,)
# Updating DUBAI Database with Bin CA194040
# (4523,)
# Updating DUBAI Database with Bin CA193050
# (4523,)
# Updating DUBAI Database with Bin CA191050
# (4523,)
# Updating DUBAI Database with Bin CA191050
# (4523,)
# Updating DUBAI Database with Bin CA194050
# (4523,)
# Updating DUBAI Database with Bin CA204010
# (4523,)
# Updating DUBAI Database with Bin CA201010
# (4523,)
# Updating DUBAI Database with Bin CA203010
# (4523,)
# Updating DUBAI Database with Bin CA204020
# (4523,)
# Updating DUBAI Database with Bin CA203020
# (4523,)
# Updating DUBAI Database with Bin CA184020
# (4523,)
# Updating DUBAI Database with Bin CA201020
# (4523,)
# Updating DUBAI Database with Bin CA184030
# (4523,)
# Updating DUBAI Database with Bin CA201030
# (4523,)
# Updating DUBAI Database with Bin CA204030
# (4523,)
# Updating DUBAI Database with Bin CA203030
# (4523,)
# Updating DUBAI Database with Bin CA184040
# (4523,)
# Updating DUBAI Database with Bin CA204040
# (4523,)
# Updating DUBAI Database with Bin CA201040
# (4523,)
# Updating DUBAI Database with Bin CA203040
# (4523,)
# Updating DUBAI Database with Bin CA184050
# (4523,)
# Updating DUBAI Database with Bin CA201050
# (4523,)
# Updating DUBAI Database with Bin CA201050
# (4523,)
# Updating DUBAI Database with Bin CA203050
# (4523,)
# Updating DUBAI Database with Bin CA204050
# (4523,)
# Updating DUBAI Database with Bin CA204050
# (4523,)
# Updating DUBAI Database with Bin CA204060
# (4523,)
# Updating DUBAI Database with Bin CA191060
# (4523,)
# Updating DUBAI Database with Bin CA184060
# (4523,)
# Updating DUBAI Database with Bin CA184010
# (4523,)
# Updating DUBAI Database with Bin CA181040
# (4523,)
# Updating DUBAI Database with Bin CA254060
# (4523,)
# Updating DUBAI Database with Bin CA261060
# (4523,)
# Updating DUBAI Database with Bin CA214010
# (4523,)
# Updating DUBAI Database with Bin CA231010
# (4523,)
# Updating DUBAI Database with Bin CA233010
# (4523,)
# Updating DUBAI Database with Bin CA211010
# (4523,)
# Updating DUBAI Database with Bin CA234010
# (4523,)
# Updating DUBAI Database with Bin CA223010
# (4523,)
# Updating DUBAI Database with Bin CA224010
# (4523,)
# Updating DUBAI Database with Bin CA221010
# (4523,)
# Updating DUBAI Database with Bin CA261010
# (4523,)
# Updating DUBAI Database with Bin CA251010
# (4523,)
# Updating DUBAI Database with Bin CA244010
# (4523,)
# Updating DUBAI Database with Bin CA243010
# (4523,)
# Updating DUBAI Database with Bin CA253010
# (4523,)
# Updating DUBAI Database with Bin CA263010
# (4523,)
# Updating DUBAI Database with Bin CA241010
# (4523,)
# Updating DUBAI Database with Bin CA254010
# (4523,)
# Updating DUBAI Database with Bin CA211020
# (4523,)
# Updating DUBAI Database with Bin CA213020
# (4523,)
# Updating DUBAI Database with Bin CA214020
# (4523,)
# Updating DUBAI Database with Bin CA231020
# (4523,)
# Updating DUBAI Database with Bin CA223020
# (4523,)
# Updating DUBAI Database with Bin CA221020
# (4523,)
# Updating DUBAI Database with Bin CA224020
# (4523,)
# Updating DUBAI Database with Bin CA251020
# (4523,)
# Updating DUBAI Database with Bin CA254020
# (4523,)
# Updating DUBAI Database with Bin CA253020
# (4523,)
# Updating DUBAI Database with Bin CA261020
# (4523,)
# Updating DUBAI Database with Bin CA263020
# (4523,)
# Updating DUBAI Database with Bin CA244020
# (4523,)
# Updating DUBAI Database with Bin CA243020
# (4523,)
# Updating DUBAI Database with Bin CA234020
# (4523,)
# Updating DUBAI Database with Bin CA241020
# (4523,)
# Updating DUBAI Database with Bin CA213010
# (4523,)
# Updating DUBAI Database with Bin CA233030
# (4523,)
# Updating DUBAI Database with Bin CA231030
# (4523,)
# Updating DUBAI Database with Bin CA234030
# (4523,)
# Updating DUBAI Database with Bin CA211030
# (4523,)
# Updating DUBAI Database with Bin CA223030
# (4523,)
# Updating DUBAI Database with Bin CA224030
# (4523,)
# Updating DUBAI Database with Bin CA244030
# (4523,)
# Updating DUBAI Database with Bin CA221030
# (4523,)
# Updating DUBAI Database with Bin CA241030
# (4523,)
# Updating DUBAI Database with Bin CA243030
# (4523,)
# Updating DUBAI Database with Bin CA214030
# (4523,)
# Updating DUBAI Database with Bin CA213030
# (4523,)
# Updating DUBAI Database with Bin CA254030
# (4523,)
# Updating DUBAI Database with Bin CA254030
# (4523,)
# Updating DUBAI Database with Bin CA261030
# (4523,)
# Updating DUBAI Database with Bin CA253030
# (4523,)
# Updating DUBAI Database with Bin CA251030
# (4523,)
# Updating DUBAI Database with Bin CA263030
# (4523,)
# Updating DUBAI Database with Bin CA211040
# (4523,)
# Updating DUBAI Database with Bin CA213040
# (4523,)
# Updating DUBAI Database with Bin CA214040
# (4523,)
# Updating DUBAI Database with Bin CA233040
# (4523,)
# Updating DUBAI Database with Bin CA223040
# (4523,)
# Updating DUBAI Database with Bin CA224040
# (4523,)
# Updating DUBAI Database with Bin CA234040
# (4523,)
# Updating DUBAI Database with Bin CA241040
# (4523,)
# Updating DUBAI Database with Bin CA253040
# (4523,)
# Updating DUBAI Database with Bin CA263040
# (4523,)
# Updating DUBAI Database with Bin CA261040
# (4523,)
# Updating DUBAI Database with Bin CA244040
# (4523,)
# Updating DUBAI Database with Bin CA214050
# (4523,)
# Updating DUBAI Database with Bin CA214050
# (4523,)
# Updating DUBAI Database with Bin CA213050
# (4523,)
# Updating DUBAI Database with Bin CA211050
# (4523,)
# Updating DUBAI Database with Bin CA211050
# (4523,)
# Updating DUBAI Database with Bin CA223050
# (4523,)
# Updating DUBAI Database with Bin CA221050
# (4523,)
# Updating DUBAI Database with Bin CA231050
# (4523,)
# Updating DUBAI Database with Bin CA233050
# (4523,)
# Updating DUBAI Database with Bin CA234050
# (4523,)
# Updating DUBAI Database with Bin CA253050
# (4523,)
# Updating DUBAI Database with Bin CA254050
# (4523,)
# Updating DUBAI Database with Bin CA243050
# (4523,)
# Updating DUBAI Database with Bin CA241050
# (4523,)
# Updating DUBAI Database with Bin CA244050
# (4523,)
# Updating DUBAI Database with Bin CA261050
# (4523,)
# Updating DUBAI Database with Bin CA251050
# (4523,)
# Updating DUBAI Database with Bin CA243040
# (4523,)
# Updating DUBAI Database with Bin CA254040
# (4523,)
# Updating DUBAI Database with Bin CA231040
# (4523,)
# Updating DUBAI Database with Bin CA221040
# (4523,)
# Updating DUBAI Database with Bin CA233020
# (4523,)
# Updating DUBAI Database with Bin CA251040
# (4523,)
# Updating DUBAI Database with Bin CA213060
# (4523,)
# Updating DUBAI Database with Bin CA231060
# (4523,)
# Updating DUBAI Database with Bin CA211060
# (4523,)
# Updating DUBAI Database with Bin CA233060
# (4523,)
# Updating DUBAI Database with Bin CA234060
# (4523,)
# Updating DUBAI Database with Bin CA253060
# (4523,)
# Updating DUBAI Database with Bin CA251060
# (4523,)
# Updating DUBAI Database with Bin CA221060
# (4523,)
# Updating DUBAI Database with Bin CA223060
# (4523,)
# Updating DUBAI Database with Bin CA241060
# (4523,)
# Updating DUBAI Database with Bin CA244060
# (4523,)
# Updating DUBAI Database with Bin CA224060
# (4523,)
# Updating DUBAI Database with Bin CA243060
# (4523,)
# Updating DUBAI Database with Bin CA224050
# (4523,)
# Updating DUBAI Database with Bin CA214060
# (4523,)
# Updating DUBAI Database with Bin CA271060
# (4523,)
# Updating DUBAI Database with Bin CA273060
# (4523,)
# Updating DUBAI Database with Bin CA274060
# (4523,)
# Updating DUBAI Database with Bin CA291060
# (4523,)
# Updating DUBAI Database with Bin CA293060
# (4523,)
# Updating DUBAI Database with Bin CA294060
# (4523,)
# Updating DUBAI Database with Bin CA311060
# (4523,)
# Updating DUBAI Database with Bin CA313060
# (4523,)
# Updating DUBAI Database with Bin CA314060
# (4523,)
# Updating DUBAI Database with Bin CA263060
# (4523,)
# Updating DUBAI Database with Bin CA264060
# (4523,)
# Updating DUBAI Database with Bin CA281060
# (4523,)
# Updating DUBAI Database with Bin CA283060
# (4523,)
# Updating DUBAI Database with Bin CA284060
# (4523,)
# Updating DUBAI Database with Bin CA301060
# (4523,)
# Updating DUBAI Database with Bin CA303060
# (4523,)
# Updating DUBAI Database with Bin CA304060
# (4523,)
# Updating DUBAI Database with Bin CA283010
# (4523,)
# Updating DUBAI Database with Bin CA281010
# (4523,)
# Updating DUBAI Database with Bin CA274010
# (4523,)
# Updating DUBAI Database with Bin CA273010
# (4523,)
# Updating DUBAI Database with Bin CA271010
# (4523,)
# Updating DUBAI Database with Bin CA264010
# (4523,)
# Updating DUBAI Database with Bin CA291010
# (4523,)
# Updating DUBAI Database with Bin CA293010
# (4523,)
# Updating DUBAI Database with Bin CA284010
# (4523,)
# Updating DUBAI Database with Bin CA294010
# (4523,)
# Updating DUBAI Database with Bin CA314010
# (4523,)
# Updating DUBAI Database with Bin CA321010
# (4523,)
# Updating DUBAI Database with Bin CA313010
# (4523,)
# Updating DUBAI Database with Bin CA311010
# (4523,)
# Updating DUBAI Database with Bin CA301010
# (4523,)
# Updating DUBAI Database with Bin CA303010
# (4523,)
# Updating DUBAI Database with Bin CA304010
# (4523,)
# Updating DUBAI Database with Bin CA271020
# (4523,)
# Updating DUBAI Database with Bin CA273020
# (4523,)
# Updating DUBAI Database with Bin CA264020
# (4523,)
# Updating DUBAI Database with Bin CA274020
# (4523,)
# Updating DUBAI Database with Bin CA294020
# (4523,)
# Updating DUBAI Database with Bin CA293020
# (4523,)
# Updating DUBAI Database with Bin CA281020
# (4523,)
# Updating DUBAI Database with Bin CA284020
# (4523,)
# Updating DUBAI Database with Bin CA283020
# (4523,)
# Updating DUBAI Database with Bin CA301020
# (4523,)
# Updating DUBAI Database with Bin CA303020
# (4523,)
# Updating DUBAI Database with Bin CA313020
# (4523,)
# Updating DUBAI Database with Bin CA311020
# (4523,)
# Updating DUBAI Database with Bin CA314020
# (4523,)
# Updating DUBAI Database with Bin CA304020
# (4523,)
# Updating DUBAI Database with Bin CA321020
# (4523,)
# Updating DUBAI Database with Bin CA274030
# (4523,)
# Updating DUBAI Database with Bin CA293030
# (4523,)
# Updating DUBAI Database with Bin CA294030
# (4523,)
# Updating DUBAI Database with Bin CA291030
# (4523,)
# Updating DUBAI Database with Bin CA271030
# (4523,)
# Updating DUBAI Database with Bin CA273030
# (4523,)
# Updating DUBAI Database with Bin CA313030
# (4523,)
# Updating DUBAI Database with Bin CA311030
# (4523,)
# Updating DUBAI Database with Bin CA284030
# (4523,)
# Updating DUBAI Database with Bin CA283030
# (4523,)
# Updating DUBAI Database with Bin CA281030
# (4523,)
# Updating DUBAI Database with Bin CA264030
# (4523,)
# Updating DUBAI Database with Bin CA301030
# (4523,)
# Updating DUBAI Database with Bin CA304030
# (4523,)
# Updating DUBAI Database with Bin CA303030
# (4523,)
# Updating DUBAI Database with Bin CA314030
# (4523,)
# Updating DUBAI Database with Bin CA271040
# (4523,)
# Updating DUBAI Database with Bin CA264040
# (4523,)
# Updating DUBAI Database with Bin CA273040
# (4523,)
# Updating DUBAI Database with Bin CA274040
# (4523,)
# Updating DUBAI Database with Bin CA293040
# (4523,)
# Updating DUBAI Database with Bin CA294040
# (4523,)
# Updating DUBAI Database with Bin CA311040
# (4523,)
# Updating DUBAI Database with Bin CA314040
# (4523,)
# Updating DUBAI Database with Bin CA281040
# (4523,)
# Updating DUBAI Database with Bin CA283040
# (4523,)
# Updating DUBAI Database with Bin CA284040
# (4523,)
# Updating DUBAI Database with Bin CA301040
# (4523,)
# Updating DUBAI Database with Bin CA303040
# (4523,)
# Updating DUBAI Database with Bin CA304040
# (4523,)
# Updating DUBAI Database with Bin CA291020
# (4523,)
# Updating DUBAI Database with Bin CA273050
# (4523,)
# Updating DUBAI Database with Bin CA273050
# (4523,)
# Updating DUBAI Database with Bin CA281050
# (4523,)
# Updating DUBAI Database with Bin CA264050
# (4523,)
# Updating DUBAI Database with Bin CA274050
# (4523,)
# Updating DUBAI Database with Bin CA263050
# (4523,)
# Updating DUBAI Database with Bin CA271050
# (4523,)
# Updating DUBAI Database with Bin CA294050
# (4523,)
# Updating DUBAI Database with Bin CA304050
# (4523,)
# Updating DUBAI Database with Bin CA293050
# (4523,)
# Updating DUBAI Database with Bin CA291050
# (4523,)
# Updating DUBAI Database with Bin CA311050
# (4523,)
# Updating DUBAI Database with Bin CA313050
# (4523,)
# Updating DUBAI Database with Bin CA314050
# (4523,)
# Updating DUBAI Database with Bin CA301050
# (4523,)
# Updating DUBAI Database with Bin CA284050
# (4523,)
# Updating DUBAI Database with Bin CA283050
# (4523,)
# Updating DUBAI Database with Bin CA303050
# (4523,)
# Updating DUBAI Database with Bin CA291040
# (4523,)
# Updating DUBAI Database with Bin CA313040
# (4523,)
# Updating DUBAI Database with Bin CD303060
# (4523,)
# Updating DUBAI Database with Bin CB011050
# (4523,)
# Updating DUBAI Database with Bin CB011050
# (4523,)
# Updating DUBAI Database with Bin A-CHK-002
# (4523,)
# Updating DUBAI Database with Bin CB111010
# (4523,)
# Updating DUBAI Database with Bin CB113010
# (4523,)
# Updating DUBAI Database with Bin CB094020
# (4523,)
# Updating DUBAI Database with Bin CB113020
# (4523,)
# Updating DUBAI Database with Bin CB114020
# (4523,)
# Updating DUBAI Database with Bin CB111020
# (4523,)
# Updating DUBAI Database with Bin CB094030
# (4523,)
# Updating DUBAI Database with Bin CB113030
# (4523,)
# Updating DUBAI Database with Bin CB111030
# (4523,)
# Updating DUBAI Database with Bin CB114030
# (4523,)
# Updating DUBAI Database with Bin CB111040
# (4523,)
# Updating DUBAI Database with Bin CB094040
# (4523,)
# Updating DUBAI Database with Bin CB111050
# (4523,)
# Updating DUBAI Database with Bin CB113050
# (4523,)
# Updating DUBAI Database with Bin CB114040
# (4523,)
# Updating DUBAI Database with Bin CB111060
# (4523,)
# Updating DUBAI Database with Bin CB114060
# (4523,)
# Updating DUBAI Database with Bin CB113060
# (4523,)
# Updating DUBAI Database with Bin CB094060
# (4523,)
# Updating DUBAI Database with Bin CB094070
# (4523,)
# Updating DUBAI Database with Bin CB114070
# (4523,)
# Updating DUBAI Database with Bin CB113070
# (4523,)
# Updating DUBAI Database with Bin CB111070
# (4523,)
# Updating DUBAI Database with Bin CB114050
# (4523,)
# Updating DUBAI Database with Bin CB113040
# (4523,)
# Updating DUBAI Database with Bin CB121010
# (4523,)
# Updating DUBAI Database with Bin CB103010
# (4523,)
# Updating DUBAI Database with Bin CB101010
# (4523,)
# Updating DUBAI Database with Bin CB121020
# (4523,)
# Updating DUBAI Database with Bin CB101020
# (4523,)
# Updating DUBAI Database with Bin CB103020
# (4523,)
# Updating DUBAI Database with Bin CB104020
# (4523,)
# Updating DUBAI Database with Bin CB104030
# (4523,)
# Updating DUBAI Database with Bin CB101030
# (4523,)
# Updating DUBAI Database with Bin CB103030
# (4523,)
# Updating DUBAI Database with Bin CB104040
# (4523,)
# Updating DUBAI Database with Bin CB103040
# (4523,)
# Updating DUBAI Database with Bin CB101040
# (4523,)
# Updating DUBAI Database with Bin CB101050
# (4523,)
# Updating DUBAI Database with Bin CB103050
# (4523,)
# Updating DUBAI Database with Bin CB104050
# (4523,)
# Updating DUBAI Database with Bin CB101060
# (4523,)
# Updating DUBAI Database with Bin CB104060
# (4523,)
# Updating DUBAI Database with Bin CB101070
# (4523,)
# Updating DUBAI Database with Bin CB103070
# (4523,)
# Updating DUBAI Database with Bin CB104070
# (4523,)
# Updating DUBAI Database with Bin CB103060
# (4523,)
# Updating DUBAI Database with Bin CB104010
# (4523,)
# Updating DUBAI Database with Bin CB114010
# (4523,)
# Updating DUBAI Database with Bin CB094050
# (4523,)
# Updating DUBAI Database with Bin CA333010
# (4523,)
# Updating DUBAI Database with Bin CA334010
# (4523,)
# Updating DUBAI Database with Bin CA331010
# (4523,)
# Updating DUBAI Database with Bin CA331020
# (4523,)
# Updating DUBAI Database with Bin CA333020
# (4523,)
# Updating DUBAI Database with Bin CA333030
# (4523,)
# Updating DUBAI Database with Bin CA331030
# (4523,)
# Updating DUBAI Database with Bin CA334030
# (4523,)
# Updating DUBAI Database with Bin CA331040
# (4523,)
# Updating DUBAI Database with Bin CA333040
# (4523,)
# Updating DUBAI Database with Bin CA334020
# (4523,)
# Updating DUBAI Database with Bin CA333050
# (4523,)
# Updating DUBAI Database with Bin CA331050
# (4523,)
# Updating DUBAI Database with Bin CA333060
# (4523,)
# Updating DUBAI Database with Bin CA334060
# (4523,)
# Updating DUBAI Database with Bin CA331060
# (4523,)
# Updating DUBAI Database with Bin CA334050
# (4523,)
# Updating DUBAI Database with Bin CA341010
# (4523,)
# Updating DUBAI Database with Bin CA323010
# (4523,)
# Updating DUBAI Database with Bin CA324010
# (4523,)
# Updating DUBAI Database with Bin CA343010
# (4523,)
# Updating DUBAI Database with Bin CA344010
# (4523,)
# Updating DUBAI Database with Bin CB033020
# (4523,)
# Updating DUBAI Database with Bin CB011020
# (4523,)
# Updating DUBAI Database with Bin CB013020
# (4523,)
# Updating DUBAI Database with Bin CB014020
# (4523,)
# Updating DUBAI Database with Bin CB031020
# (4523,)
# Updating DUBAI Database with Bin CA323020
# (4523,)
# Updating DUBAI Database with Bin CA324020
# (4523,)
# Updating DUBAI Database with Bin CA343020
# (4523,)
# Updating DUBAI Database with Bin CA341020
# (4523,)
# Updating DUBAI Database with Bin CB031030
# (4523,)
# Updating DUBAI Database with Bin CB033030
# (4523,)
# Updating DUBAI Database with Bin CA323030
# (4523,)
# Updating DUBAI Database with Bin CA324030
# (4523,)
# Updating DUBAI Database with Bin CA321030
# (4523,)
# Updating DUBAI Database with Bin CA344030
# (4523,)
# Updating DUBAI Database with Bin CA343030
# (4523,)
# Updating DUBAI Database with Bin CA341030
# (4523,)
# Updating DUBAI Database with Bin CB011040
# (4523,)
# Updating DUBAI Database with Bin CB033040
# (4523,)
# Updating DUBAI Database with Bin CB031040
# (4523,)
# Updating DUBAI Database with Bin CB014040
# (4523,)
# Updating DUBAI Database with Bin CA321040
# (4523,)
# Updating DUBAI Database with Bin CA323040
# (4523,)
# Updating DUBAI Database with Bin CA324040
# (4523,)
# Updating DUBAI Database with Bin CA343040
# (4523,)
# Updating DUBAI Database with Bin CB014050
# (4523,)
# Updating DUBAI Database with Bin CB031050
# (4523,)
# Updating DUBAI Database with Bin CA341040
# (4523,)
# Updating DUBAI Database with Bin CA324050
# (4523,)
# Updating DUBAI Database with Bin CA321050
# (4523,)
# Updating DUBAI Database with Bin CA344050
# (4523,)
# Updating DUBAI Database with Bin CB013060
# (4523,)
# Updating DUBAI Database with Bin CB011060
# (4523,)
# Updating DUBAI Database with Bin CB031060
# (4523,)
# Updating DUBAI Database with Bin CB014060
# (4523,)
# Updating DUBAI Database with Bin CA061060
# (4523,)
# Updating DUBAI Database with Bin CA063060
# (4523,)
# Updating DUBAI Database with Bin CA323050
# (4523,)
# Updating DUBAI Database with Bin CA321060
# (4523,)
# Updating DUBAI Database with Bin CA323060
# (4523,)
# Updating DUBAI Database with Bin CA341060
# (4523,)
# Updating DUBAI Database with Bin CA343060
# (4523,)
# Updating DUBAI Database with Bin CA344060
# (4523,)
# Updating DUBAI Database with Bin CB011070
# (4523,)
# Updating DUBAI Database with Bin CB013070
# (4523,)
# Updating DUBAI Database with Bin CB031070
# (4523,)
# Updating DUBAI Database with Bin CB013050
# (4523,)
# Updating DUBAI Database with Bin CA324060
# (4523,)
# Updating DUBAI Database with Bin CA061070
# (4523,)
# Updating DUBAI Database with Bin CB011030
# (4523,)
# Updating DUBAI Database with Bin CA063070
# (4523,)
# Updating DUBAI Database with Bin CB014030
# (4523,)
# Updating DUBAI Database with Bin CB013030
# (4523,)
# Updating DUBAI Database with Bin CA344040
# (4523,)
# Updating DUBAI Database with Bin CA344040
# (4523,)
# Updating DUBAI Database with Bin CA344020
# (4523,)
# Updating DUBAI Database with Bin CB024020
# (4523,)
# Updating DUBAI Database with Bin CB021020
# (4523,)
# Updating DUBAI Database with Bin CB024040
# (4523,)
# Updating DUBAI Database with Bin CB021040
# (4523,)
# Updating DUBAI Database with Bin CB023040
# (4523,)
# Updating DUBAI Database with Bin CB021050
# (4523,)
# Updating DUBAI Database with Bin CB023050
# (4523,)
# Updating DUBAI Database with Bin CB021060
# (4523,)
# Updating DUBAI Database with Bin CB023060
# (4523,)
# Updating DUBAI Database with Bin CB024060
# (4523,)
# Updating DUBAI Database with Bin CB024050
# (4523,)
# Updating DUBAI Database with Bin CB021030
# (4523,)
# Updating DUBAI Database with Bin CB021070
# (4523,)
# Updating DUBAI Database with Bin CB024070
# (4523,)
# Updating DUBAI Database with Bin CB023070
# (4523,)
# Updating DUBAI Database with Bin CB023030
# (4523,)
# Updating DUBAI Database with Bin CB024030
# (4523,)
# Updating DUBAI Database with Bin CB013040
# (4523,)
# Updating DUBAI Database with Bin CA341050
# (4523,)
# Updating DUBAI Database with Bin CA334040
# (4523,)
# Updating DUBAI Database with Bin CA343050
# (4523,)
# Updating DUBAI Database with Bin CB014070
# (4523,)
# Updating DUBAI Database with Bin CB023020
# (4523,)
# Updating DUBAI Database with Bin CK011010
# (4523,)
# Updating DUBAI Database with Bin CK012010
# (4523,)
# Updating DUBAI Database with Bin CK013010
# (4523,)
# Updating DUBAI Database with Bin CK014010
# (4523,)
# Updating DUBAI Database with Bin CH314010
# (4523,)
# Updating DUBAI Database with Bin CH331010
# (4523,)
# Updating DUBAI Database with Bin CH333010
# (4523,)
# Updating DUBAI Database with Bin CH334010
# (4523,)
# Updating DUBAI Database with Bin CH313020
# (4523,)
# Updating DUBAI Database with Bin CH314020
# (4523,)
# Updating DUBAI Database with Bin CH333020
# (4523,)
# Updating DUBAI Database with Bin CH334020
# (4523,)
# Updating DUBAI Database with Bin CH331020
# (4523,)
# Updating DUBAI Database with Bin CH314030
# (4523,)
# Updating DUBAI Database with Bin CH331030
# (4523,)
# ...
# Updating DUBAI Database with Bin CG133060
# (4523,)
# Updating DUBAI Database with Bin CG143070
# (4523,)
# Updating DUBAI Database with Bin CG143070
# (4523,)
# Updating DUBAI Database with Bin CG141070
# (4523,)
# Updating DUBAI Database with Bin CG141070
# (4523,)
# Updating DUBAI Database with Bin CG141070
# (4523,)
# Updating DUBAI Database with Bin CG144070
# (4523,)
# Updating DUBAI Database with Bin CG151020
# (4523,)
# Updating DUBAI Database with Bin CG111060
# (4523,)
# Updating DUBAI Database with Bin CG153050
# (4523,)
# Updating DUBAI Database with Bin CG151070
# (4523,)
# Updating DUBAI Database with Bin CG151070
# (4523,)
# Updating DUBAI Database with Bin CG111010
# (4523,)
# Updating DUBAI Database with Bin CG093010
# (4523,)
# Updating DUBAI Database with Bin CG093010
# (4523,)
# Updating DUBAI Database with Bin CG103050
# (4523,)
# Updating DUBAI Database with Bin CG094030
# (4523,)
# Updating DUBAI Database with Bin CG134010
# (4523,)
# Updating DUBAI Database with Bin CG141010
# (4523,)
# Updating DUBAI Database with Bin CG124020
# (4523,)
# Updating DUBAI Database with Bin CG103030
# (4523,)
# Updating DUBAI Database with Bin CG101030
# (4523,)
# Updating DUBAI Database with Bin CG133030
# (4523,)
# Updating DUBAI Database with Bin CG131030
# (4523,)
# Updating DUBAI Database with Bin CG114030
# (4523,)
# Updating DUBAI Database with Bin CG143030
# (4523,)
# Updating DUBAI Database with Bin CG144030
# (4523,)
# Updating DUBAI Database with Bin CG141030
# (4523,)
# Updating DUBAI Database with Bin CG121030
# (4523,)
# Updating DUBAI Database with Bin CG083040
# (4523,)
# Updating DUBAI Database with Bin CG103040
# (4523,)
# Updating DUBAI Database with Bin CG101040
# (4523,)
# Updating DUBAI Database with Bin CG084040
# (4523,)
# Updating DUBAI Database with Bin CG104040
# (4523,)
# Updating DUBAI Database with Bin CG121040
# (4523,)
# Updating DUBAI Database with Bin CG123040
# (4523,)
# Updating DUBAI Database with Bin CG124040
# (4523,)
# Updating DUBAI Database with Bin CG141040
# (4523,)
# Updating DUBAI Database with Bin CG144040
# (4523,)
# Updating DUBAI Database with Bin CG153040
# (4523,)
# Updating DUBAI Database with Bin CG074050
# (4523,)
# Updating DUBAI Database with Bin CG091050
# (4523,)
# Updating DUBAI Database with Bin CG113050
# (4523,)
# Updating DUBAI Database with Bin CG143050
# (4523,)
# Updating DUBAI Database with Bin CG131050
# (4523,)
# Updating DUBAI Database with Bin CG074060
# (4523,)
# Updating DUBAI Database with Bin CG134060
# (4523,)
# Updating DUBAI Database with Bin CG123060
# (4523,)
# Updating DUBAI Database with Bin CG144060
# (4523,)
# Updating DUBAI Database with Bin CG141060
# (4523,)
# Updating DUBAI Database with Bin CG083070
# (4523,)
# Updating DUBAI Database with Bin CG101070
# (4523,)
# Updating DUBAI Database with Bin CG113070
# (4523,)
# Updating DUBAI Database with Bin CG111070
# (4523,)
# Updating DUBAI Database with Bin CG123070
# (4523,)
# Updating DUBAI Database with Bin CG124070
# (4523,)
# Updating DUBAI Database with Bin CG151060
# (4523,)
# Updating DUBAI Database with Bin CG134070
# (4523,)
# Updating DUBAI Database with Bin CG134070
# (4523,)
# Updating DUBAI Database with Bin CG113030
# (4523,)
# Updating DUBAI Database with Bin CG143060
# (4523,)
# Updating DUBAI Database with Bin CG081050
# (4523,)
# Updating DUBAI Database with Bin CG143040
# (4523,)
# Updating DUBAI Database with Bin CG084060
# (4523,)
# Updating DUBAI Database with Bin CG084060
# (4523,)
# Updating DUBAI Database with Bin CG094020
# (4523,)
# Updating DUBAI Database with Bin CG083060
# (4523,)
# Updating DUBAI Database with Bin CG113020
# (4523,)
# Updating DUBAI Database with Bin CG083030
# (4523,)
# Updating DUBAI Database with Bin CG131020
# (4523,)
# Updating DUBAI Database with Bin CG153070
# (4523,)
# Updating DUBAI Database with Bin CG094040
# (4523,)
# Updating DUBAI Database with Bin CG094040
# (4523,)
# Updating DUBAI Database with Bin CG094040
# (4523,)
# Updating DUBAI Database with Bin CG123030
# (4523,)
# Updating DUBAI Database with Bin CG123030
# (4523,)
# Updating DUBAI Database with Bin CG123030
# (4523,)
# Updating DUBAI Database with Bin CG131070
# (4523,)
# Updating DUBAI Database with Bin CG124050
# (4523,)
# Updating DUBAI Database with Bin CG123020
# (4523,)
# Updating DUBAI Database with Bin CG123020
# (4523,)
# Updating DUBAI Database with Bin CG123020
# (4523,)
# Updating DUBAI Database with Bin CG013020
# (4523,)
# Updating DUBAI Database with Bin CG113060
# (4523,)
# Updating DUBAI Database with Bin CG113060
# (4523,)
# Updating DUBAI Database with Bin CG113060
# (4523,)
# Updating DUBAI Database with Bin CG124060
# (4523,)
# Updating DUBAI Database with Bin CG184010
# (4523,)
# Updating DUBAI Database with Bin CG161010
# (4523,)
# Updating DUBAI Database with Bin CG174010
# (4523,)
# Updating DUBAI Database with Bin CG163010
# (4523,)
# Updating DUBAI Database with Bin CG194010
# (4523,)
# Updating DUBAI Database with Bin CG193010
# (4523,)
# Updating DUBAI Database with Bin CG191010
# (4523,)
# Updating DUBAI Database with Bin CG183010
# (4523,)
# Updating DUBAI Database with Bin CG181010
# (4523,)
# Updating DUBAI Database with Bin CG154020
# (4523,)
# Updating DUBAI Database with Bin CG161020
# (4523,)
# Updating DUBAI Database with Bin CG173020
# (4523,)
# Updating DUBAI Database with Bin CG194020
# (4523,)
# Updating DUBAI Database with Bin CG183020
# (4523,)
# Updating DUBAI Database with Bin CG193030
# (4523,)
# Updating DUBAI Database with Bin CG154030
# (4523,)
# Updating DUBAI Database with Bin CG173030
# (4523,)
# Updating DUBAI Database with Bin CG163030
# (4523,)
# Updating DUBAI Database with Bin CG183030
# (4523,)
# Updating DUBAI Database with Bin CG181030
# (4523,)
# Updating DUBAI Database with Bin CG184030
# (4523,)
# Updating DUBAI Database with Bin CG194030
# (4523,)
# Updating DUBAI Database with Bin CG171040
# (4523,)
# Updating DUBAI Database with Bin CG174040
# (4523,)
# Updating DUBAI Database with Bin CG164040
# (4523,)
# Updating DUBAI Database with Bin CG163040
# (4523,)
# Updating DUBAI Database with Bin CG181040
# (4523,)
# Updating DUBAI Database with Bin CG184040
# (4523,)
# Updating DUBAI Database with Bin CG194040
# (4523,)
# Updating DUBAI Database with Bin CG193040
# (4523,)
# Updating DUBAI Database with Bin CG193050
# (4523,)
# Updating DUBAI Database with Bin CG194050
# (4523,)
# Updating DUBAI Database with Bin CG154050
# (4523,)
# Updating DUBAI Database with Bin CG161050
# (4523,)
# Updating DUBAI Database with Bin CG181060
# (4523,)
# Updating DUBAI Database with Bin CG184060
# (4523,)
# Updating DUBAI Database with Bin CG173060
# (4523,)
# Updating DUBAI Database with Bin CG171060
# (4523,)
# Updating DUBAI Database with Bin CG193060
# (4523,)
# Updating DUBAI Database with Bin CG171010
# (4523,)
# Updating DUBAI Database with Bin CG171030
# (4523,)
# Updating DUBAI Database with Bin CG184020
# (4523,)
# Updating DUBAI Database with Bin CG171050
# (4523,)
# Updating DUBAI Database with Bin CG154070
# (4523,)
# Updating DUBAI Database with Bin CG164070
# (4523,)
# Updating DUBAI Database with Bin CG163070
# (4523,)
# Updating DUBAI Database with Bin CG161070
# (4523,)
# Updating DUBAI Database with Bin CG201020
# (4523,)
# Updating DUBAI Database with Bin CG193020
# (4523,)
# Updating DUBAI Database with Bin CG171020
# (4523,)
# Updating DUBAI Database with Bin CG174030
# (4523,)
# Updating DUBAI Database with Bin CG173070
# (4523,)
# Updating DUBAI Database with Bin CG174070
# (4523,)
# Updating DUBAI Database with Bin CG181070
# (4523,)
# Updating DUBAI Database with Bin CG183070
# (4523,)
# Updating DUBAI Database with Bin CG184070
# (4523,)
# Updating DUBAI Database with Bin CG161030
# (4523,)
# Updating DUBAI Database with Bin CG181050
# (4523,)
# Updating DUBAI Database with Bin CG191070
# (4523,)
# Updating DUBAI Database with Bin CG164010
# (4523,)
# Updating DUBAI Database with Bin CG193070
# (4523,)
# Updating DUBAI Database with Bin CG181020
# (4523,)
# Updating DUBAI Database with Bin CG191020
# (4523,)
# Updating DUBAI Database with Bin CG161060
# (4523,)
# Updating DUBAI Database with Bin CG201010
# (4523,)
# Updating DUBAI Database with Bin CG154040
# (4523,)
# Updating DUBAI Database with Bin CG161040
# (4523,)
# Updating DUBAI Database with Bin CG191040
# (4523,)
# Updating DUBAI Database with Bin CG183040
# (4523,)
# Updating DUBAI Database with Bin CG201040
# (4523,)
# Updating DUBAI Database with Bin CG174050
# (4523,)
# Updating DUBAI Database with Bin CG164050
# (4523,)
# Updating DUBAI Database with Bin CG191050
# (4523,)
# Updating DUBAI Database with Bin CG183050
# (4523,)
# Updating DUBAI Database with Bin CG184050
# (4523,)
# Updating DUBAI Database with Bin CG163050
# (4523,)
# Updating DUBAI Database with Bin CG154060
# (4523,)
# Updating DUBAI Database with Bin CG163060
# (4523,)
# Updating DUBAI Database with Bin CG164060
# (4523,)
# Updating DUBAI Database with Bin CG183060
# (4523,)
# Updating DUBAI Database with Bin CG191060
# (4523,)
# Updating DUBAI Database with Bin CG174060
# (4523,)
# Updating DUBAI Database with Bin CG194060
# (4523,)
# Updating DUBAI Database with Bin CG174020
# (4523,)
# Updating DUBAI Database with Bin CG171070
# (4523,)
# Updating DUBAI Database with Bin CG194070
# (4523,)
# Updating DUBAI Database with Bin CG173050
# (4523,)
# Updating DUBAI Database with Bin CG164030
# (4523,)
# Updating DUBAI Database with Bin CG164020
# (4523,)
# Updating DUBAI Database with Bin CG191030
# (4523,)
# Updating DUBAI Database with Bin CG163020
# (4523,)
# Updating DUBAI Database with Bin CG173010
# (4523,)
# Updating DUBAI Database with Bin CG201030
# (4523,)
# Updating DUBAI Database with Bin CG201030
# (4523,)
# Updating DUBAI Database with Bin CG201030
# (4523,)
# Updating DUBAI Database with Bin CG084030
# (4523,)
# Updating DUBAI Database with Bin CG081030
# (4523,)
# Updating DUBAI Database with Bin CG104030
# (4523,)
# Updating DUBAI Database with Bin CG124030
# (4523,)
# Updating DUBAI Database with Bin CG074040
# (4523,)
# Updating DUBAI Database with Bin CG091040
# (4523,)
# Updating DUBAI Database with Bin CG093040
# (4523,)
# Updating DUBAI Database with Bin CG111040
# (4523,)
# Updating DUBAI Database with Bin CG081040
# (4523,)
# Updating DUBAI Database with Bin CG133040
# (4523,)
# Updating DUBAI Database with Bin CG113040
# (4523,)
# Updating DUBAI Database with Bin CG131040
# (4523,)
# Updating DUBAI Database with Bin CG114040
# (4523,)
# Updating DUBAI Database with Bin CG134040
# (4523,)
# Updating DUBAI Database with Bin CG151040
# (4523,)
# Updating DUBAI Database with Bin CG093050
# (4523,)
# Updating DUBAI Database with Bin CG094050
# (4523,)
# Updating DUBAI Database with Bin CG111050
# (4523,)
# Updating DUBAI Database with Bin CG114050
# (4523,)
# Updating DUBAI Database with Bin CG083050
# (4523,)
# Updating DUBAI Database with Bin CG084050
# (4523,)
# Updating DUBAI Database with Bin CG101050
# (4523,)
# Updating DUBAI Database with Bin CG104050
# (4523,)
# Updating DUBAI Database with Bin CG121050
# (4523,)
# Updating DUBAI Database with Bin CG123050
# (4523,)
# Updating DUBAI Database with Bin CG133050
# (4523,)
# Updating DUBAI Database with Bin CG151050
# (4523,)
# Updating DUBAI Database with Bin CG144050
# (4523,)
# Updating DUBAI Database with Bin CG141050
# (4523,)
# Updating DUBAI Database with Bin CG081060
# (4523,)
# Updating DUBAI Database with Bin CG091060
# (4523,)
# Updating DUBAI Database with Bin CG093060
# (4523,)
# Updating DUBAI Database with Bin CG094060
# (4523,)
# Updating DUBAI Database with Bin CG114060
# (4523,)
# Updating DUBAI Database with Bin CG101060
# (4523,)
# Updating DUBAI Database with Bin CG103060
# (4523,)
# Updating DUBAI Database with Bin CG104060
# (4523,)
# Updating DUBAI Database with Bin CG121060
# (4523,)
# Updating DUBAI Database with Bin CG131060
# (4523,)
# Updating DUBAI Database with Bin CG153060
# (4523,)
# Updating DUBAI Database with Bin CG074070
# (4523,)
# Updating DUBAI Database with Bin CG094070
# (4523,)
# Updating DUBAI Database with Bin CG093070
# (4523,)
# Updating DUBAI Database with Bin CG091070
# (4523,)
# Updating DUBAI Database with Bin CG084070
# (4523,)
# Updating DUBAI Database with Bin CG081070
# (4523,)
# Updating DUBAI Database with Bin CG103070
# (4523,)
# Updating DUBAI Database with Bin CG104070
# (4523,)
# Updating DUBAI Database with Bin CG114070
# (4523,)
# Updating DUBAI Database with Bin CG121070
# (4523,)
# Updating DUBAI Database with Bin CG133070
# (4523,)
# Updating DUBAI Database with Bin CG134050
# (4523,)
# Updating DUBAI Database with Bin CG133060
# (4523,)
# Updating DUBAI Database with Bin CG143070
# (4523,)
# Updating DUBAI Database with Bin CG143070
# (4523,)
# Updating DUBAI Database with Bin CG141070
# (4523,)
# Updating DUBAI Database with Bin CG141070
# (4523,)
# Updating DUBAI Database with Bin CG141070
# (4523,)
# Updating DUBAI Database with Bin CG144070
# (4523,)
# Updating DUBAI Database with Bin CG111060
# (4523,)
# Updating DUBAI Database with Bin CG153050
# (4523,)
# Updating DUBAI Database with Bin CG151070
# (4523,)
# Updating DUBAI Database with Bin CG151070
# (4523,)
# Updating DUBAI Database with Bin CG103050
# (4523,)
# Updating DUBAI Database with Bin CG103030
# (4523,)
# Updating DUBAI Database with Bin CG101030
# (4523,)
# Updating DUBAI Database with Bin CG121030
# (4523,)
# Updating DUBAI Database with Bin CG083040
# (4523,)
# Updating DUBAI Database with Bin CG103040
# (4523,)
# Updating DUBAI Database with Bin CG101040
# (4523,)
# Updating DUBAI Database with Bin CG084040
# (4523,)
# Updating DUBAI Database with Bin CG104040
# (4523,)
# Updating DUBAI Database with Bin CG121040
# (4523,)
# Updating DUBAI Database with Bin CG123040
# (4523,)
# Updating DUBAI Database with Bin CG124040
# (4523,)
# Updating DUBAI Database with Bin CG141040
# (4523,)
# Updating DUBAI Database with Bin CG144040
# (4523,)
# Updating DUBAI Database with Bin CG153040
# (4523,)
# Updating DUBAI Database with Bin CG074050
# (4523,)
# Updating DUBAI Database with Bin CG091050
# (4523,)
# Updating DUBAI Database with Bin CG113050
# (4523,)
# Updating DUBAI Database with Bin CG143050
# (4523,)
# Updating DUBAI Database with Bin CG131050
# (4523,)
# Updating DUBAI Database with Bin CG074060
# (4523,)
# Updating DUBAI Database with Bin CG134060
# (4523,)
# Updating DUBAI Database with Bin CG123060
# (4523,)
# Updating DUBAI Database with Bin CG144060
# (4523,)
# Updating DUBAI Database with Bin CG141060
# (4523,)
# Updating DUBAI Database with Bin CG083070
# (4523,)
# Updating DUBAI Database with Bin CG101070
# (4523,)
# Updating DUBAI Database with Bin CG113070
# (4523,)
# Updating DUBAI Database with Bin CG111070
# (4523,)
# Updating DUBAI Database with Bin CG123070
# (4523,)
# Updating DUBAI Database with Bin CG124070
# (4523,)
# Updating DUBAI Database with Bin CG151060
# (4523,)
# Updating DUBAI Database with Bin CG134070
# (4523,)
# Updating DUBAI Database with Bin CG134070
# (4523,)
# Updating DUBAI Database with Bin CG143060
# (4523,)
# Updating DUBAI Database with Bin CG081050
# (4523,)
# Updating DUBAI Database with Bin CG143040
# (4523,)
# Updating DUBAI Database with Bin CG084060
# (4523,)
# Updating DUBAI Database with Bin CG084060
# (4523,)
# Updating DUBAI Database with Bin CG083060
# (4523,)
# Updating DUBAI Database with Bin CG083030
# (4523,)
# Updating DUBAI Database with Bin CG153070
# (4523,)
# Updating DUBAI Database with Bin CG094040
# (4523,)
# Updating DUBAI Database with Bin CG094040
# (4523,)
# Updating DUBAI Database with Bin CG094040
# (4523,)
# Updating DUBAI Database with Bin CG123030
# (4523,)
# Updating DUBAI Database with Bin CG123030
# (4523,)
# Updating DUBAI Database with Bin CG123030
# (4523,)
# Updating DUBAI Database with Bin CG131070
# (4523,)
# Updating DUBAI Database with Bin CG124050
# (4523,)
# Updating DUBAI Database with Bin CG173040
# (4523,)
# Updating DUBAI Database with Bin CG213010
# (4523,)
# Updating DUBAI Database with Bin CG214010
# (4523,)
# Updating DUBAI Database with Bin CG233010
# (4523,)
# Updating DUBAI Database with Bin CG234010
# (4523,)
# Updating DUBAI Database with Bin CG231010
# (4523,)
# Updating DUBAI Database with Bin CG251010
# (4523,)
# Updating DUBAI Database with Bin CG271010
# (4523,)
# Updating DUBAI Database with Bin CG254010
# (4523,)
# Updating DUBAI Database with Bin CG253010
# (4523,)
# Updating DUBAI Database with Bin CG264010
# (4523,)
# Updating DUBAI Database with Bin CG263010
# (4523,)
# Updating DUBAI Database with Bin CG273010
# (4523,)
# Updating DUBAI Database with Bin CG281010
# (4523,)
# Updating DUBAI Database with Bin CG283010
# (4523,)
# Updating DUBAI Database with Bin CG301010
# (4523,)
# Updating DUBAI Database with Bin CG304010
# (4523,)
# Updating DUBAI Database with Bin CG303010
# (4523,)
# Updating DUBAI Database with Bin CG294010
# (4523,)
# Updating DUBAI Database with Bin CG291010
# (4523,)
# Updating DUBAI Database with Bin CG293010
# (4523,)
# Updating DUBAI Database with Bin CG311010
# (4523,)
# Updating DUBAI Database with Bin CG211010
# (4523,)
# Updating DUBAI Database with Bin CG274010
# (4523,)
# Updating DUBAI Database with Bin CG284010
# (4523,)
